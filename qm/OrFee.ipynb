# %% [markdown]
# # OrFée

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()

# %%
data = pd.read_csv("data.csv", index_col=0, parse_dates=['date']).dropna()
data.drop(['index'], axis=1, inplace=True)
data.drop(data[data['age'] < 0].index, inplace=True)
data.drop(data[data['exp'] < 0].index, inplace=True)
data.drop(data[data['note'] > 100].index, inplace=True)

y = data.pop('embauche')
X = data

X[['age', 'note']] /= 100

# %%
X.columns
# Out:
# Index(['date', 'cheveux', 'age', 'exp', 'salaire', 'sexe', 'diplome',
#        'specialite', 'note', 'dispo'],
#       dtype='object')

# %%
sns.heatmap(X.corr())

# %%
X['day'] = X['date'].transform(lambda x: x.day)
X['month'] = X['date'].transform(lambda x: x.month)
X['year'] = X['date'].transform(lambda x: x.year)
X.drop(['date'], axis=1, inplace=True)

# %%
sns.barplot(X['year'], y, X['month'])

# %%
sns.lineplot(X['note'], y)

# %%
sns.barplot(X['cheveux'], y, X['sexe'])

# %%
sns.barplot(X['diplome'], y, X['specialite'])

# %%
sns.lineplot(X['exp'], y)

# %%
sns.scatterplot(X['note'], X['salaire'], y)

# %%
sns.barplot(X['diplome'], y)

# %%
sns.barplot(X['specialite'], y)

# %%
sns.barplot(X['sexe'], X['note'], y)

# %%
sns.barplot(X['dispo'], X['note'], y)

# %%
cat = ['cheveux', 'sexe', 'diplome', 'specialite', 'dispo', 'day', 'month', 'year']
#X = pd.get_dummies(X, columns=cat)
